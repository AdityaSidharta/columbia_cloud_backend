# %%
event = {'resource': '/upload', 'path': '/upload', 'httpMethod': 'POST', 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br', 'Content-Type': 'image/jpeg', 'Host': '7q3xdayda5.execute-api.us-east-1.amazonaws.com', 'Postman-Token': '9763811f-8a6d-4ee3-9e95-0717566e9667', 'User-Agent': 'PostmanRuntime/7.29.2', 'X-Amzn-Trace-Id': 'Root=1-638e43a5-16417b996e9a1b7460057834', 'X-Forwarded-For': '160.39.125.224', 'X-Forwarded-Port': '443', 'X-Forwarded-Proto': 'https'}, 'multiValueHeaders': {'Accept': ['*/*'], 'Accept-Encoding': ['gzip, deflate, br'], 'Content-Type': ['image/jpeg'], 'Host': ['7q3xdayda5.execute-api.us-east-1.amazonaws.com'], 'Postman-Token': ['9763811f-8a6d-4ee3-9e95-0717566e9667'], 'User-Agent': ['PostmanRuntime/7.29.2'], 'X-Amzn-Trace-Id': ['Root=1-638e43a5-16417b996e9a1b7460057834'], 'X-Forwarded-For': ['160.39.125.224'], 'X-Forwarded-Port': ['443'], 'X-Forwarded-Proto': ['https']}, 'queryStringParameters': None, 'multiValueQueryStringParameters': None, 'pathParameters': None, 'stageVariables': None, 'requestContext': {'resourceId': 'fzrnnf', 'resourcePath': '/upload', 'httpMethod': 'POST', 'extendedRequestId': 'cr-B0FwiIAMFdGw=', 'requestTime': '05/Dec/2022:19:16:53 +0000', 'path': '/dev/upload', 'accountId': '078528452492', 'protocol': 'HTTP/1.1', 'stage': 'dev', 'domainPrefix': '7q3xdayda5', 'requestTimeEpoch': 1670267813011, 'requestId': '9699e7dc-b88b-4639-9343-d16cd07a88a1', 'identity': {'cognitoIdentityPoolId': None, 'accountId': None, 'cognitoIdentityId': None, 'caller': None, 'sourceIp': '160.39.125.224', 'principalOrgId': None, 'accessKey': None, 'cognitoAuthenticationType': None, 'cognitoAuthenticationProvider': None, 'userArn': None, 'userAgent': 'PostmanRuntime/7.29.2', 'user': None}, 'domainName': '7q3xdayda5.execute-api.us-east-1.amazonaws.com', 'apiId': '7q3xdayda5'}, 'body': '...', 'isBase64Encoded': True}

# %%
event['body']
# Out:
# '...'

# %%
event['headers']
# Out:
# {'Accept': '*/*',
#  'Accept-Encoding': 'gzip, deflate, br',
#  'Content-Type': 'image/jpeg',
#  'Host': '7q3xdayda5.execute-api.us-east-1.amazonaws.com',
#  'Postman-Token': '9763811f-8a6d-4ee3-9e95-0717566e9667',
#  'User-Agent': 'PostmanRuntime/7.29.2',
#  'X-Amzn-Trace-Id': 'Root=1-638e43a5-16417b996e9a1b7460057834',
#  'X-Forwarded-For': '160.39.125.224',
#  'X-Forwarded-Port': '443',
#  'X-Forwarded-Proto': 'https'}

# %%
# !pip install pillow
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import base64
from PIL import Image
from io import BytesIO

# %%
Image.open(BytesIO(base64.b64decode(event['body'])))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=163x310 at 0x7FD9D53522E8>

# %%
from boto3 import Session

# %%
client = session.client('rekognition')

# %%
image = {'Bytes': BytesIO(base64.b64decode(event['body'])).read()}

# %%
response = client.detect_text(Image=image)

# %%
textDetections=response['TextDetections']

# %%
texts = []
for text in textDetections:
    texts.append(text['DetectedText'])
texts = ' '.join(texts)

# %%
runtime= session.client('runtime.sagemaker')
# Out:
# 'St Lucie County Tribune April 6, 1906 CLEVELAND TO BUILD A HOME AT STUART Lately it has been learned that ex- President Grover Cleveland, who for many winters her been coming south to Stuart, in the northern part of Dade county, has purchased a plot of land in the town and will erect & substantial winter home thereon. The seller WAS Ernest Stypman and the deed will be re- curded in Miami within the next few days. says the Tropical Sun. All the world knows that Grover Cleveland la an enthuniastic fisherman and all the world knows also that Florida St Lucie County Tribune April 6, 1906 CLEVELAND TO BUILD A HOME AT STUART Lately it has been learned that ex- President Grover Cleveland, who for many winters her been coming south to Stuart, in the northern part of Dade county, has purchased a plot of land in the town and will erect & substantial winter home thereon. The seller WAS Ernest Stypman and the deed will be re- curded in Miami within the next few days. says the Tropical Sun. All 
# ...
